# %%
import pandas as pd

# %%
filename = "/sdf/home/j/jneveu/rubin-user/holo_202501/auxtel_atmosphere_202311_v3.2.1_fixA2fixA1_RobustFit_newThroughputs.parquet.gz"

# %%
# !ls ../../../../../../jneveu/holo_202501/auxtel_atmosphere_202311_v3.2.1_fixA2fixA1_RobustFit_newThroughputs.parquet.gz

# %%
filename = "../../../../../../jneveu/holo_202501/auxtel_atmosphere_202311_v3.2.1_fixA2fixA1_RobustFit_newThroughputs.parquet.gz"

# %%
df = pd.read_parquet(filename)

# %%
df

# %%
ls  ../../../../../fromjeremy/holo_202601/auxtel_atmosphere_202311_v3.2.1_fixA2fixA1_RobustFit_newThroughputs.parquet.gz

# %%
filename = "../../../../../fromjeremy/holo_202601/auxtel_atmosphere_202311_v3.2.1_fixA2fixA1_RobustFit_newThroughputs.parquet.gz"

# %%
df = pd.read_parquet(filename)

# %%
df
